# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import pandas as pd

books = pd.read_csv("books_cleaned.csv")

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195                                          I Am that
# 5196                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5192                              Nayantara Sahgal
# 5193                                 Hermann Hesse
# 5194                                  Robin Sharma
# 5195  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5196                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5192        Indic fiction (English)
# 5193              Adventure stories
# 5194               Health & Fitness
# 5195                     Philosophy
# 5196                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5192  http://books.google.com/books/content?id=q-tKP...
# 5193  http://books.google.com/books/content?id=rq6JP...
# 5194  http://books.google.com/books/content?id=c_7mf...
# 5195  http://books.google.com/books/content?id=Fv_JP...
# 5196  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5192  On A Train Journey Home To North India After L...          2003.0
# 5193  This book tells the tale of a man who goes on ...          2002.0
# 5194  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5195  This collection of the timeless teachings of o...          1999.0
# 5196  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 1               3.83      241.0         5164.0
# 2               3.93      512.0        29532.0
# 3               4.15      170.0        33684.0
# 4               4.09      176.0        37569.0
# ...              ...        ...            ...
# 5192            2.93      324.0            0.0
# 5193            3.70      175.0           24.0
# 5194            3.82      198.0         1568.0
# 5195            4.51      531.0          104.0
# 5196            0.00      210.0            0.0
#
#                                     tittle_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195     I Am that: Talks with Sri Nisargadatta Maharaj
# 5196                           The Berlin Phenomenology
#
#                                      tagged_description
# 0     9780002005883 A NOVEL THAT READERS and critics...
# 1     9780002261982 A new 'Christie for Christmas' -...
# 2     9780006178736 A memorable, mesmerizing heroine...
# 3     9780006280897 Lewis' work on the nature of lov...
# 4     9780006280934 "In The Problem of Pain, C.S. Le...
# ...                                                 ...
# 5192  9788172235222 On A Train Journey Home To North...
# 5193  9788173031014 This book tells the tale of a ma...
# 5194  9788179921623 Wisdom to Create a Life of Passi...
# 5195  9788185300535 This collection of the timeless ...
# 5196  9789027712059 Since the three volume edition o...
#
# [5197 rows x 13 columns]

# %%
books["tagged_description"]
# Out:
# 0       9780002005883 A NOVEL THAT READERS and critics...
# 1       9780002261982 A new 'Christie for Christmas' -...
# 2       9780006178736 A memorable, mesmerizing heroine...
# 3       9780006280897 Lewis' work on the nature of lov...
# 4       9780006280934 "In The Problem of Pain, C.S. Le...
#                               ...
# 5192    9788172235222 On A Train Journey Home To North...
# 5193    9788173031014 This book tells the tale of a ma...
# 5194    9788179921623 Wisdom to Create a Life of Passi...
# 5195    9788185300535 This collection of the timeless ...
# 5196    9789027712059 Since the three volume edition o...
# Name: tagged_description, Length: 5197, dtype: object

# %%
books["tagged_description"].to_csv("tagged_description.txt",
                                   sep = "\n",
                                   index = False,
                                   header = False)

# %%
raw_documents = TextLoader("tagged_description.txt", encoding="utf-8").load()
text_splitter = CharacterTextSplitter(chunk_size=1200, chunk_overlap=0, separator="\n")
documents = text_splitter.split_documents(raw_documents)
# Out:
# Created a chunk of size 1214, which is longer than the specified 1200
# Created a chunk of size 1267, which is longer than the specified 1200
# Created a chunk of size 2010, which is longer than the specified 1200
# Created a chunk of size 1225, which is longer than the specified 1200
# Created a chunk of size 1214, which is longer than the specified 1200
# Created a chunk of size 1270, which is longer than the specified 1200
# Created a chunk of size 1635, which is longer than the specified 1200
# Created a chunk of size 1325, which is longer than the specified 1200
# Created a chunk of size 2012, which is longer than the specified 1200
# Created a chunk of size 1286, which is longer than the specified 1200
# Created a chunk of size 1231, which is longer than the specified 1200
# Created a chunk of size 1242, which is longer than the specified 1200
# Created a chunk of size 1318, which is longer than the specified 1200
# Created a chunk of size 2834, which is longer than the specified 1200
# Created a chunk of size 2510, which is longer than the specified 1200
# Created a chunk of size 1422, which is longer than the specified 1200
# Created a chunk of size 1268, which is longer than the specified 1200
# Created a chunk of size 1812, which is longer than the specified 1200
# Created a chunk of size 1830, which is longer than the specified 1200
# Created a chunk of size 1284, which is longer than the specified 1200
# Created a chunk of size 1642, which is longer than the specified 1200
# Created a chunk of size 1930, which is longer than the specified 1200
# Created a chunk of size 2008, which is longer than the specified 1200
# Created a chunk of size 2285, which is longer than the specified 1200
# Created a chunk of size 1483, which is longer than the specified 1200
# Created a chunk of size 1912, which is longer than the specified 1200
# Created a chunk of size 2616, which is longer than the specified 1200
# Created a chunk of size 1580, which is longer than the specified 1200
# Created a chunk of size 1530, which is longer than the specified 1200
# Created a chunk of size 2030, which is longer than the specified 1200
# Created a chunk of size 1619, which is longer than the specified 1200
# Created a chunk of size 1282, which is longer than the specified 1200
# Created a chunk of size 1268, which is longer than the specified 1200
# Created a chunk of size 1277, which is longer than the specified 1200
# Created a chunk of size 2762, which is longer than the specified 1200
# Created a chunk of size 1224, which is longer than the specified 1200
# Created a chunk of size 1805, which is longer than the specified 1200
# Created a chunk of size 1268, which is longer than the specified 1200
# Created a chunk of size 1771, which is longer than the specified 1200
# Created a chunk of size 1270, which is longer than the specified 1200
# Created a chunk of size 1715, which is longer than the specified 1200
# Created a chunk of size 1681, which is longer than the specified 1200
# Created a chunk of size 2005, which is longer than the specified 1200
# Created a chunk of size 2141, which is longer than the specified 1200
# Created a chunk of size 1322, which is longer than the specified 1200
# Created a chunk of size 1316, which is longer than the specified 1200
# Created a chunk of size 1255, which is longer than the specified 1200
# Created a chunk of size 1550, which is longer than the specified 1200
# Created a chunk of size 1652, which is longer than the specified 1200
# Created a chunk of size 1495, which is longer than the specified 1200
# Created a chunk of size 1277, which is longer than the specified 1200
# Created a chunk of size 1666, which is longer than the specified 1200
# Created a chunk of size 1616, which is longer than the specified 1200
# Created a chunk of size 1597, which is longer than the specified 1200
# Created a chunk of size 1960, which is longer than the specified 1200
# Created a chunk of size 1708, which is longer than the specified 1200
# Created a chunk of size 1947, which is longer than the specified 1200
# Created a chunk of size 1807, which is longer than the specified 1200
# Created a chunk of size 1518, which is longer than the specified 1200
# Created a chunk of size 1259, which is longer than the specified 1200
# Created a chunk of size 1480, which is longer than the specified 1200
# Created a chunk of size 1443, which is longer than the specified 1200
# Created a chunk of size 1266, which is longer than the specified 1200
# Created a chunk of size 1369, which is longer than the specified 1200
# Created a chunk of size 1622, which is longer than the specified 1200
# Created a chunk of size 1357, which is longer than the specified 1200
# Created a chunk of size 1394, which is longer than the specified 1200
# Created a chunk of size 1216, which is longer than the specified 1200
# Created a chunk of size 2209, which is longer than the specified 1200
# Created a chunk of size 1371, which is longer than the specified 1200
# Created a chunk of size 2877, which is longer than the specified 1200
# Created a chunk of size 1279, which is longer than the specified 1200
# Created a chunk of size 1714, which is longer than the specified 1200
# Created a chunk of size 1638, which is longer than the specified 1200
# Created a chunk of size 2398, which is longer than the specified 1200
# Created a chunk of size 2120, which is longer than the specified 1200
# Created a chunk of size 1488, which is longer than the specified 1200
# Created a chunk of size 1691, which is longer than the specified 1200
# Created a chunk of size 1418, which is longer than the specified 1200
# Created a chunk of size 1359, which is longer than the specified 1200
# Created a chunk of size 2181, which is longer than the specified 1200
# Created a chunk of size 2171, which is longer than the specified 1200
# Created a chunk of size 1454, which is longer than the specified 1200
# Created a chunk of size 1454, which is longer than the specified 1200
# Created a chunk of size 1973, which is longer than the specified 1200
# Created a chunk of size 1987, which is longer than the specified 1200
# Created a chunk of size 1648, which is longer than the specified 1200
# Created a chunk of size 2723, which is longer than the specified 1200
# Created a chunk of size 1632, which is longer than the specified 1200
# Created a chunk of size 1284, which is longer than the specified 1200
# Created a chunk of size 1484, which is longer than the specified 1200
# Created a chunk of size 1216, which is longer than the specified 1200
# Created a chunk of size 2456, which is longer than the specified 1200
# Created a chunk of size 1349, which is longer than the specified 1200
# Created a chunk of size 1271, which is longer than the specified 1200
# Created a chunk of size 1548, which is longer than the specified 1200
# Created a chunk of size 1201, which is longer than the specified 1200
# Created a chunk of size 1774, which is longer than the specified 1200
# Created a chunk of size 1323, which is longer than the specified 1200
# Created a chunk of size 1213, which is longer than the specified 1200
# Created a chunk of size 1598, which is longer than the specified 1200
# Created a chunk of size 1963, which is longer than the specified 1200
# Created a chunk of size 2450, which is longer than the specified 1200
# Created a chunk of size 1796, which is longer than the specified 1200
# Created a chunk of size 1568, which is longer than the specified 1200
# Created a chunk of size 1219, which is longer than the specified 1200
# Created a chunk of size 1380, which is longer than the specified 1200
# Created a chunk of size 1452, which is longer than the specified 1200
# Created a chunk of size 1298, which is longer than the specified 1200
# Created a chunk of size 1761, which is longer than the specified 1200
# Created a chunk of size 1629, which is longer than the specified 1200
# Created a chunk of size 1593, which is longer than the specified 1200
# Created a chunk of size 1587, which is longer than the specified 1200
# Created a chunk of size 1259, which is longer than the specified 1200
# Created a chunk of size 1533, which is longer than the specified 1200
# Created a chunk of size 1202, which is longer than the specified 1200
# Created a chunk of size 1247, which is longer than the specified 1200
# Created a chunk of size 1211, which is longer than the specified 1200
# Created a chunk of size 1352, which is longer than the specified 1200
# Created a chunk of size 1412, which is longer than the specified 1200
# Created a chunk of size 1216, which is longer than the specified 1200
# Created a chunk of size 1891, which is longer than the specified 1200
# Created a chunk of size 3168, which is longer than the specified 1200
# Created a chunk of size 1532, which is longer than the specified 1200
# Created a chunk of size 1588, which is longer than the specified 1200
# Created a chunk of size 1609, which is longer than the specified 1200
# Created a chunk of size 1623, which is longer than the specified 1200
# Created a chunk of size 1419, which is longer than the specified 1200
# Created a chunk of size 1211, which is longer than the specified 1200
# Created a chunk of size 2034, which is longer than the specified 1200
# Created a chunk of size 1436, which is longer than the specified 1200
# Created a chunk of size 1471, which is longer than the specified 1200
# Created a chunk of size 1436, which is longer than the specified 1200
# Created a chunk of size 1330, which is longer than the specified 1200
# Created a chunk of size 1721, which is longer than the specified 1200
# Created a chunk of size 1530, which is longer than the specified 1200
# Created a chunk of size 1651, which is longer than the specified 1200
# Created a chunk of size 1579, which is longer than the specified 1200
# Created a chunk of size 1646, which is longer than the specified 1200
# Created a chunk of size 1687, which is longer than the specified 1200
# Created a chunk of size 2031, which is longer than the specified 1200
# Created a chunk of size 1338, which is longer than the specified 1200
# Created a chunk of size 1226, which is longer than the specified 1200
# Created a chunk of size 1235, which is longer than the specified 1200
# Created a chunk of size 2940, which is longer than the specified 1200
# Created a chunk of size 1490, which is longer than the specified 1200
# Created a chunk of size 1208, which is longer than the specified 1200
# Created a chunk of size 1489, which is longer than the specified 1200
# Created a chunk of size 1802, which is longer than the specified 1200
# Created a chunk of size 1595, which is longer than the specified 1200
# Created a chunk of size 1361, which is longer than the specified 1200
# Created a chunk of size 1643, which is longer than the specified 1200
# Created a chunk of size 1382, which is longer than the specified 1200
# Created a chunk of size 1763, which is longer than the specified 1200
# Created a chunk of size 1971, which is longer than the specified 1200
# Created a chunk of size 1240, which is longer than the specified 1200
# Created a chunk of size 1280, which is longer than the specified 1200
# Created a chunk of size 1475, which is longer than the specified 1200
# Created a chunk of size 1268, which is longer than the specified 1200
# Created a chunk of size 1219, which is longer than the specified 1200
# Created a chunk of size 1246, which is longer than the specified 1200
# Created a chunk of size 1290, which is longer than the specified 1200
# Created a chunk of size 1564, which is longer than the specified 1200
# Created a chunk of size 1214, which is longer than the specified 1200
# Created a chunk of size 1215, which is longer than the specified 1200
# Created a chunk of size 1255, which is longer than the specified 1200
# Created a chunk of size 1263, which is longer than the specified 1200
# Created a chunk of size 1620, which is longer than the specified 1200
# Created a chunk of size 1579, which is longer than the specified 1200
# Created a chunk of size 1450, which is longer than the specified 1200
# Created a chunk of size 1443, which is longer than the specified 1200
# Created a chunk of size 1285, which is longer than the specified 1200
# Created a chunk of size 1309, which is longer than the specified 1200
# Created a chunk of size 1922, which is longer than the specified 1200
# Created a chunk of size 1912, which is longer than the specified 1200
# Created a chunk of size 2146, which is longer than the specified 1200
# Created a chunk of size 2490, which is longer than the specified 1200
# Created a chunk of size 1373, which is longer than the specified 1200
# Created a chunk of size 1475, which is longer than the specified 1200
# Created a chunk of size 1965, which is longer than the specified 1200
# Created a chunk of size 1621, which is longer than the specified 1200
# Created a chunk of size 3784, which is longer than the specified 1200
# Created a chunk of size 1446, which is longer than the specified 1200
# Created a chunk of size 1492, which is longer than the specified 1200
# Created a chunk of size 2702, which is longer than the specified 1200
# Created a chunk of size 5836, which is longer than the specified 1200
# Created a chunk of size 1709, which is longer than the specified 1200
# Created a chunk of size 1678, which is longer than the specified 1200
# Created a chunk of size 1808, which is longer than the specified 1200
# Created a chunk of size 1739, which is longer than the specified 1200
# Created a chunk of size 1616, which is longer than the specified 1200
# Created a chunk of size 1477, which is longer than the specified 1200
# Created a chunk of size 1348, which is longer than the specified 1200
# Created a chunk of size 1441, which is longer than the specified 1200
# Created a chunk of size 1866, which is longer than the specified 1200
# Created a chunk of size 1464, which is longer than the specified 1200
# Created a chunk of size 1277, which is longer than the specified 1200
# Created a chunk of size 1756, which is longer than the specified 1200
# Created a chunk of size 1555, which is longer than the specified 1200
# Created a chunk of size 1960, which is longer than the specified 1200
# Created a chunk of size 2075, which is longer than the specified 1200
# Created a chunk of size 1482, which is longer than the specified 1200
# Created a chunk of size 1469, which is longer than the specified 1200
# Created a chunk of size 1370, which is longer than the specified 1200
# Created a chunk of size 1381, which is longer than the specified 1200
# Created a chunk of size 1345, which is longer than the specified 1200
# Created a chunk of size 1343, which is longer than the specified 1200
# Created a chunk of size 1456, which is longer than the specified 1200
# Created a chunk of size 2002, which is longer than the specified 1200
# Created a chunk of size 1853, which is longer than the specified 1200
# Created a chunk of size 1362, which is longer than the specified 1200
# Created a chunk of size 1581, which is longer than the specified 1200
# Created a chunk of size 1201, which is longer than the specified 1200
# Created a chunk of size 1510, which is longer than the specified 1200
# Created a chunk of size 1480, which is longer than the specified 1200
# Created a chunk of size 1326, which is longer than the specified 1200
# Created a chunk of size 1307, which is longer than the specified 1200
# Created a chunk of size 1431, which is longer than the specified 1200
# Created a chunk of size 1314, which is longer than the specified 1200
# Created a chunk of size 1415, which is longer than the specified 1200
# Created a chunk of size 1863, which is longer than the specified 1200
# Created a chunk of size 1379, which is longer than the specified 1200
# Created a chunk of size 1519, which is longer than the specified 1200
# Created a chunk of size 1432, which is longer than the specified 1200
# Created a chunk of size 1246, which is longer than the specified 1200
# Created a chunk of size 1549, which is longer than the specified 1200
# Created a chunk of size 2082, which is longer than the specified 1200
# Created a chunk of size 1248, which is longer than the specified 1200
# Created a chunk of size 2297, which is longer than the specified 1200
# Created a chunk of size 2071, which is longer than the specified 1200
# Created a chunk of size 1428, which is longer than the specified 1200
# Created a chunk of size 1739, which is longer than the specified 1200
# Created a chunk of size 1261, which is longer than the specified 1200
# Created a chunk of size 2021, which is longer than the specified 1200
# Created a chunk of size 2022, which is longer than the specified 1200
# Created a chunk of size 1267, which is longer than the specified 1200
# Created a chunk of size 1294, which is longer than the specified 1200
# Created a chunk of size 1250, which is longer than the specified 1200
# Created a chunk of size 1406, which is longer than the specified 1200
# Created a chunk of size 1395, which is longer than the specified 1200
# Created a chunk of size 1533, which is longer than the specified 1200
# Created a chunk of size 1344, which is longer than the specified 1200
# Created a chunk of size 1435, which is longer than the specified 1200
# Created a chunk of size 1219, which is longer than the specified 1200
# Created a chunk of size 1321, which is longer than the specified 1200
# Created a chunk of size 1442, which is longer than the specified 1200
# Created a chunk of size 1625, which is longer than the specified 1200
# Created a chunk of size 1333, which is longer than the specified 1200
# Created a chunk of size 2372, which is longer than the specified 1200
# Created a chunk of size 1679, which is longer than the specified 1200
# Created a chunk of size 1334, which is longer than the specified 1200
# Created a chunk of size 1307, which is longer than the specified 1200
# Created a chunk of size 1981, which is longer than the specified 1200
# Created a chunk of size 1627, which is longer than the specified 1200
# Created a chunk of size 1297, which is longer than the specified 1200
# Created a chunk of size 1745, which is longer than the specified 1200
# Created a chunk of size 1201, which is longer than the specified 1200
# Created a chunk of size 1722, which is longer than the specified 1200
# Created a chunk of size 1528, which is longer than the specified 1200
# Created a chunk of size 1327, which is longer than the specified 1200
# Created a chunk of size 1382, which is longer than the specified 1200
# Created a chunk of size 2351, which is longer than the specified 1200
# Created a chunk of size 1850, which is longer than the specified 1200
# Created a chunk of size 1280, which is longer than the specified 1200
# Created a chunk of size 1392, which is longer than the specified 1200
# Created a chunk of size 1432, which is longer than the specified 1200
# Created a chunk of size 1526, which is longer than the specified 1200
# Created a chunk of size 1299, which is longer than the specified 1200
# Created a chunk of size 1262, which is longer than the specified 1200
# Created a chunk of size 1222, which is longer than the specified 1200
# Created a chunk of size 1283, which is longer than the specified 1200
# Created a chunk of size 1328, which is longer than the specified 1200
# Created a chunk of size 1789, which is longer than the specified 1200
# Created a chunk of size 1476, which is longer than the specified 1200
# Created a chunk of size 1654, which is longer than the specified 1200
# Created a chunk of size 1354, which is longer than the specified 1200
# Created a chunk of size 1363, which is longer than the specified 1200
# Created a chunk of size 2350, which is longer than the specified 1200
# Created a chunk of size 1650, which is longer than the specified 1200
# Created a chunk of size 1528, which is longer than the specified 1200
# Created a chunk of size 1995, which is longer than the specified 1200
# Created a chunk of size 1352, which is longer than the specified 1200
# Created a chunk of size 1400, which is longer than the specified 1200
# Created a chunk of size 1745, which is longer than the specified 1200
# Created a chunk of size 2334, which is longer than the specified 1200
# Created a chunk of size 2946, which is longer than the specified 1200
# Created a chunk of size 3243, which is longer than the specified 1200
# Created a chunk of size 2780, which is longer than the specified 1200
# Created a chunk of size 1309, which is longer than the specified 1200
# Created a chunk of size 2085, which is longer than the specified 1200
# Created a chunk of size 1897, which is longer than the specified 1200
# Created a chunk of size 2018, which is longer than the specified 1200
# Created a chunk of size 1933, which is longer than the specified 1200
# Created a chunk of size 1365, which is longer than the specified 1200
# Created a chunk of size 1751, which is longer than the specified 1200
# Created a chunk of size 2713, which is longer than the specified 1200
# Created a chunk of size 2278, which is longer than the specified 1200
# Created a chunk of size 1204, which is longer than the specified 1200
# Created a chunk of size 1435, which is longer than the specified 1200
# Created a chunk of size 1340, which is longer than the specified 1200
# Created a chunk of size 2051, which is longer than the specified 1200
# Created a chunk of size 1305, which is longer than the specified 1200
# Created a chunk of size 2014, which is longer than the specified 1200
# Created a chunk of size 1273, which is longer than the specified 1200
# Created a chunk of size 1360, which is longer than the specified 1200
# Created a chunk of size 1731, which is longer than the specified 1200
# Created a chunk of size 2067, which is longer than the specified 1200
# Created a chunk of size 1326, which is longer than the specified 1200
# Created a chunk of size 1352, which is longer than the specified 1200
# Created a chunk of size 1903, which is longer than the specified 1200
# Created a chunk of size 1310, which is longer than the specified 1200
# Created a chunk of size 1621, which is longer than the specified 1200
# Created a chunk of size 1283, which is longer than the specified 1200
# Created a chunk of size 1475, which is longer than the specified 1200
# Created a chunk of size 1772, which is longer than the specified 1200
# Created a chunk of size 1502, which is longer than the specified 1200
# Created a chunk of size 1544, which is longer than the specified 1200
# Created a chunk of size 2855, which is longer than the specified 1200
# Created a chunk of size 1214, which is longer than the specified 1200
# Created a chunk of size 1472, which is longer than the specified 1200
# Created a chunk of size 1471, which is longer than the specified 1200
# Created a chunk of size 1215, which is longer than the specified 1200
# Created a chunk of size 1862, which is longer than the specified 1200
# Created a chunk of size 1525, which is longer than the specified 1200
# Created a chunk of size 1385, which is longer than the specified 1200
# Created a chunk of size 1452, which is longer than the specified 1200
# Created a chunk of size 1360, which is longer than the specified 1200
# Created a chunk of size 1341, which is longer than the specified 1200
# Created a chunk of size 1338, which is longer than the specified 1200
# Created a chunk of size 1601, which is longer than the specified 1200
# Created a chunk of size 1267, which is longer than the specified 1200
# Created a chunk of size 1432, which is longer than the specified 1200
# Created a chunk of size 2869, which is longer than the specified 1200
# Created a chunk of size 2347, which is longer than the specified 1200
# Created a chunk of size 2451, which is longer than the specified 1200
# Created a chunk of size 1510, which is longer than the specified 1200
# Created a chunk of size 1512, which is longer than the specified 1200
# Created a chunk of size 1300, which is longer than the specified 1200
# Created a chunk of size 1348, which is longer than the specified 1200
# Created a chunk of size 1340, which is longer than the specified 1200
# Created a chunk of size 1298, which is longer than the specified 1200
# Created a chunk of size 1320, which is longer than the specified 1200
# Created a chunk of size 1524, which is longer than the specified 1200
# Created a chunk of size 1255, which is longer than the specified 1200
# Created a chunk of size 1293, which is longer than the specified 1200
# Created a chunk of size 1350, which is longer than the specified 1200
# Created a chunk of size 1403, which is longer than the specified 1200
# Created a chunk of size 1898, which is longer than the specified 1200
# Created a chunk of size 2149, which is longer than the specified 1200
# Created a chunk of size 1417, which is longer than the specified 1200
# Created a chunk of size 1419, which is longer than the specified 1200
# Created a chunk of size 1387, which is longer than the specified 1200
# Created a chunk of size 1280, which is longer than the specified 1200
# Created a chunk of size 1287, which is longer than the specified 1200
# Created a chunk of size 2742, which is longer than the specified 1200
# Created a chunk of size 3938, which is longer than the specified 1200
# Created a chunk of size 1273, which is longer than the specified 1200
# Created a chunk of size 1964, which is longer than the specified 1200
# Created a chunk of size 1529, which is longer than the specified 1200
# Created a chunk of size 1302, which is longer than the specified 1200
# Created a chunk of size 1272, which is longer than the specified 1200
# Created a chunk of size 1655, which is longer than the specified 1200

# %%
documents[0]
# Out:
# Document(metadata={'source': 'tagged_description.txt'}, page_content='9780002005883 A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.')

# %%
db_books = Chroma.from_documents(
    documents,
    embedding=OpenAIEmbeddings())

# %%
query = "A book to teach children about nature"
docs = db_books.similarity_search(query, k = 10)
docs
# Out:
# [Document(id='53770ce7-25bc-4869-be10-dfa1249edb13', metadata={'source': 'tagged_description.txt'}, page_content="9780786808380 Introduce your babies to birds, cats, dogs, and babies through fine art, illustration, and photographs. These books are a rare opportunity to expose little ones to a range of images on a single subject, from simple child's drawings and abstract art to playful photos. A brief text accompanies each image, introducing the baby to some basic -- and sometimes playful -- information about the subjects.\n9780786808397 Introduce your baby to birds, cats, dogs, and babies through fine art, illustration, and photographs. These books are a rare opportunity to exopse little ones to a range of images on a single subject, from simple child's drawings and abstract art to playful photos. A brief text accompanies each image, introducing baby to some basic -- and sometimes playful -- information about the subjects.\n9780786808717 A very special puddle sets Violet the mouse off on her latest nature discovery. It is through this puddle that Violet observes the effect rain has on the world around her. A Mylar puddle on the last page offers children a chance to see their reflection in a puddle, just like Violet!"),
#  Document(id='8e037872-6b34-43b1-8897-109082a26b70', metadata={'source': 'tagged_description.txt'}, page_content='9780374299194 The author describes growing up in a family of all boys in Webster Groves, Missouri, reflecting on such topics as the dynamics of a Christian youth fellowship, his role as the school prankster, his marriage, and the life lessons he has learned from birds.\n9780374422080 This Newbery Honor Book tells the story of 11 -year-old Primrose, who lives in a small fishing village in British Columbia. She recounts her experiences and all she learns about human nature and the unpredictability of life after her parents are lost at sea.'),
#  Document(id='e099bd4a-fd41-4111-bed1-346ec97a0462', metadata={'source': 'tagged_description.txt'}, page_content="9780762427321 Hawking's revolutionary look at the scientific discoveries that changed people's perceptions of the world now comes complete with color photographs and illustrations depicting theoretical models of the planets and their orbits.\n9780763619312 When a third grade classmate gets her picture in the paper for winning a spelling bee, Judy is determined to find a way to become famous herself.\n9780763620875 When Judy Moody gets serious about protecting the environment, her little brother Stink thinks she is overdoing it, but she manages to inspire her third grade class to undertake an award-winning, environment-saving project. Reprint.\n9780763621643 As a page in his uncle's castle in thirteenth-century England, eleven-year-old Tobias records in his journal his experiences learning how to hunt, play games of skill, and behave in noble society.\n9780763625894 Edward Tulane, a cold-hearted and proud toy rabbit, loves only himself until he is separated from the little girl who adores him and travels across the country, acquiring new owners and listening to their hopes, dreams, and histories. Jr Lib Guild. Teacher's Guide available. 300,000 first printing."),
#  Document(id='dcb7cde3-4193-4868-8215-b4c11cf7ecd6', metadata={'source': 'tagged_description.txt'}, page_content='"9780067575208 First published more than three decades ago, this reissue of Rachel Carson\'s award-winning classic brings her unique vision to a new generation of readers. Stunning new photographs by Nick Kelsh beautifully complement Carson\'s intimate account of adventures with her young nephew, Roger, as they enjoy walks along the rocky coast of Maine and through dense forests and open fields, observing wildlife, strange plants, moonlight and storm clouds, and listening to the ""living music"" of insects in the underbrush. ""If a child is to keep alive his inborn sense of wonder."" Writes Carson, ""he needs the companionship of at least one adult who can share it, rediscovering with him the joy, excitement and mystery of the world we live in."" The Sense of Wonder is a refreshing antidote to indifference and a guide to capturing the simple power of discovery that Carson views as essential to life. In her insightful new introduction, Linda Lear remembers Rachel Carson\'s groundbreaking achievements in the context of the legend
#  Document(id='52d6d589-b438-4eec-be52-152b31cf59d6', metadata={'source': 'tagged_description.txt'}, page_content='9780006646006 Joe and his parents are enjoying a summer holiday by the sea at the Ocean Star Hotel. The sky is bright blue, the sun shines and Joe loves all that the seaside has to offer. But when the fog rolls in and rain falls Joe begins to wish that he was back at home again. Things change, however, when the owner of the hotel invites Joe to share in a magical world, only a few steps away. The loft is black as night but then above Joe\'s head a thousand tiny stars begin to sparkle and in the distance he hears the chug-chug-chug of a model train. A whole world is soon to open up before Joe\'s eyes, a world of snow-capped mountains, great deserts, and rocking fishing boats.\n"9780007105045 ""The two works \'On fairy-stories\' and \'Leaf by Niggle\' were first brought together to form the book \'Tree and leaf\' in 1964. In this new edition a third element is added: the poem Mythopoeia, the making of myths...""--Preface."'),
#  Document(id='88f13079-454c-41ad-8629-5456cd1a1932', metadata={'source': 'tagged_description.txt'}, page_content="9780786719051 The Golden Age of Science Fiction, from the early 1940s through the 1950s, saw an explosion of talent in SF writing, including authors such as Isaac Asimov, Robert A. Heinlein, and Arthur C. Clarke. Their writing helped science fiction gain wide public attention, and left a lasting impression upon society. The same writers formed the mold for the next three decades of science fiction, and much of their writing remains as fresh today as it was then.\n9780786808069 Children will discover the exciting world of their own backyard in this introduction to familiar animals from cats and dogs to bugs and frogs. The combination of photographs, illustrations, and fun facts make this an accessible and delightful learning experience.\n9780786808373 Introducing your baby to birds, cats, dogs, and babies through fine art, illsutration and photographs. These books are a rare opportunity to expose little ones to a range of images on a single subject, from simple child's drawings and abstract art to playful photos. A brief text accompanies each image, introducing baby to some basic -- and sometimes playful -- information on the subjects."),
#  Document(id='c0ff600c-bb3c-4d93-9440-2e39701108fb', metadata={'source': 'tagged_description.txt'}, page_content="9780762404780 Collection of traditional blessings, classic verse, and photographs from throughout Ireland. A timeless tribute to the beauty of the land and the character of its people.\n9780762408283 This carry-along version of our enormously popular Zen Gardening Kit provides a touch of tranquility on the go. Packaged with a 32page introduction to the aesthetic enlightenment of Zen gardening, it includes a tray, fine sand, decorative rocks, and miniature wooden rake.\n9780762413935 Award-winning English illustrator Christian Birmingham--one of the rising stars of children's illustration--brings eight time-honored fairy tales to life in dazzling, full-color artwork for this charming collection. Sure to become a treasured part of any childhood library, this sumptuously illustrated book includes the read-aloud favorites The Ugly Duckling, Thumbelina, The Steadfast Tin Soldier, The Emperor's New Clothes, The Little Match Girl, The Little Mermaid, The Nightingale, and The Princess and the Pea.\n9780762419227 Looks at landmark mathematical discoveries over the past 2500 years by such mathematicians as Euclid, Isaac Newton, Pierre Simon de Laplace, Gerog Cantor, and Alan Turing.")]

# %%
books[books["isbn13"] == int(docs[0].page_content.split()[0].strip())]
# Out:
#              isbn13      isbn10                  title             authors  \
# 3749  9780786808380  0786808381  Baby Einstein: Babies  Julie Aigner-Clark
#
#             categories                                          thumbnail  \
# 3749  Juvenile Fiction  http://books.google.com/books/content?id=jv4NA...
#
#                                             description  published_year  \
# 3749  Introduce your babies to birds, cats, dogs, an...          2002.0
#
#       average_rating  num_pages  ratings_count    tittle_and_subtitle  \
# 3749            4.03       20.0           29.0  Baby Einstein: Babies
#
#                                      tagged_description
# 3749  9780786808380 Introduce your babies to birds, ...

# %%
def retrieve_semantic_recommendations(
        query: str,
        top_k: int = 10,
) -> pd.DataFrame:
    recs = db_books.similarity_search(query, k = 50)

    books_list = []

    for i in range(0, len(recs)):
        books_list += [int(recs[i].page_content.strip('"').split()[0])]

    return books[books["isbn13"].isin